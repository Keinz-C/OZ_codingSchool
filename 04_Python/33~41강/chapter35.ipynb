# %% [markdown]
# [예외객체]
# - Exception을 사용하면 예외의 종류에 대해 알 수 있다.

# %%
try:
    x, y = map(int, input('밑변과 높이를 입력해주세요').split(" "))
    print('삼각형의 넓이는 {0}입니다'.format(x*y/2))
except:
    print("정수로 입력하지 않아 계산이 불가합니다.")

# %%
try:
    x, y = map(int, input('밑변과 높이를 입력해주세요').split(" "))
    print('삼각형의 넓이는 {0}입니다'.format(x*y/2))
except Exception as exception:
    print("type(exception):", type(exception))
    print("exception:", exception)
# Out:
# 밑변과 높이를 입력해주세요sdf
# type(exception): <class 'ValueError'>
# exception: invalid literal for int() with base 10: 'sdf'

# %% [markdown]
# 예외객체 자료형은 Value Error이고
# 내용은 invalid literal for int() with base 10: 'sdf'이다.
#
# [예외 구분하기]
# 여러 가지 예외가 발생하는 상황을 구분지어 대비하기 위함

# %%
numbers = [23, 11, 7, 4, 12]

try:
    number_input = int(input("찾고싶은 값의 위치를 입력해주세요."))
    print(f'{number_input}번째 요소 : {numbers[number_input]}')
except Exception as exception:
    print("type(exception):", type(exception))
    print("exception:", exception)
# Out:
# 찾고싶은 값의 위치를 입력해주세요.2
# 2번째 요소 : 7

# %% [markdown]
# [except : list index out of range]와 같은 에러를 구분하고처리할 수 있는 기능을 파이썬에서 제공한다.
#
# ```
# try:
#     예외가 발생할 가능성이 있는 구문
# except 예외 a:
#     예외 a가 발생했을 때 실행할 구문
# except 예외 b:
#     예외 b가 발생했을 때 실행할 구문
# except 예외 c:
#     예외 c가 발생했을 때 실행할 구문
# ```

# %%
numbers = [23, 11, 7, 4, 12]

try:
    number_input = int(input("찾고싶은 값의 위치를 입력해주세요."))
    print(f'{number_input}번째 요소 : {numbers[number_input]}')
except ValueError:
    print("정수로 입력해주세요")
except IndexError:
    print("리스트의 범위를 벗어났습니다. 입력값을 다시 확인해주세요.")
# Out:
# 찾고싶은 값의 위치를 입력해주세요.300
# 리스트의 범위를 벗어났습니다. 입력값을 다시 확인해주세요.

# %% [markdown]
# [예외 구분 구문과 예외 객체]
# as 키워드를 이용해 as exception을 사용할 수 있음

# %%
numbers = [23, 11, 7, 4, 12]

try:
    number_input = int(input("찾고싶은 값의 위치를 입력해주세요."))
    print(f'{number_input}번째 요소 : {numbers[number_input]}')
except ValueError as exception:
    print("정수로 입력해주세요")
    print("Exception:", exception)
except IndexError as exception:
    print("리스트의 범위를 벗어났습니다. 입력값을 다시 확인해주세요.")
    print("Exception:", exception)
# Out:
# 찾고싶은 값의 위치를 입력해주세요.1000
# 리스트의 범위를 벗어났습니다. 입력값을 다시 확인해주세요.
# Exception: list index out of range

# %% [markdown]
# 프로그램 실행 중 위 2가지 예외처리로 처리가 불가능한 경우를 대비해 앞서 사용했던
# 모든 예외처리가 가능한 Exception을 이용해 대처할 수 있다.

# %%
numbers = [23, 11, 7, 4, 12]

try:
    number_input = int(input("찾고싶은 값의 위치를 입력해주세요."))
    print(f'{number_input}번째 요소 : {numbers[number_input]}')
    에러를.만들기위한
except ValueError as exception:
    print("정수로 입력해주세요")
    print("Exception:", exception)
except IndexError as exception:
    print("리스트의 범위를 벗어났습니다. 입력값을 다시 확인해주세요.")
    print("Exception:", exception)
except Exception as exception:
    print("대처 불가한 예외가 발생했습니다.")
    print("Exception:", exception)
# Out:
# 찾고싶은 값의 위치를 입력해주세요.3
# 3번째 요소 : 4
# 대체 불가한 예외가 발생했습니다.
# Exception: name '에러를' is not defined

# %% [markdown]
# ####예외 구분 구문의 이해
# - 예외 종류와 그에 대한 설명(구글링 필요)

# %%
#1. 예외 종류와 그에 대한 설명
# KeyError : 주로 딕셔너리에서 발생하는 에러로, 없는 Key 값에 접근하려 할 때 발생
# ValueError : 부적절한 값을 가진 인자를 받았을 때 발생하는 에러
# SyntaxError : 문법 오류, 조건문에서 :을 빼먹거나 문법에 오류가 있을 때 발생
# NameError : 지역변수, 전역변수의 이름을 찾을 수 없는 경우 발생
# ZeroDivisionError : 숫자를 0으로 나누려할 때 발생하는 에러
# FileNotFoundError : 존재하지 않는 파일이나 디렉토리에 접근하려 할 때
# TypeError : 서로 다른 타입으로 연산하려고 할 때
# AttributeError : 잘못된 메서드나 속성을 호출하거나 대입했을 때 발생
# ConnectionError : 서버를 켜지 않았을 때 발생
