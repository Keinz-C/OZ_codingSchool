# %%
#주석을 작성해보자!
print('진짜 안 보일까...?')
# print("거짓말이야...")
print("와...ctrl+/로도 주석처리가 되네...?")
# Out:
# 진짜 안 보일까...?
# 와...ctrl+/로도 주석처리가 되네...?

# %%
# print('진짜 안 보일까...?')
# # print("거짓말이야...")
# print("와...ctrl+/로도 주석처리가 되네...?")
print("colab에서는 쌍따옴표 6개가 안먹혀 ㅠㅠ")
# Out:
# colab에서는 쌍따옴표 6개가 안먹혀 ㅠㅠ

# %%
for 동물 in ("토끼", "사자", "푸바오", "호랑이"):
    print(동물)
    print("동물원 가zooA~~~~~~~")
# Out:
# 토끼
# 동물원 가zooA~~~~~~~
# 사자
# 동물원 가zooA~~~~~~~
# 푸바오
# 동물원 가zooA~~~~~~~
# 호랑이
# 동물원 가zooA~~~~~~~

# %%
for 동물 in ("토끼", "사자", "푸바오", "호랑이"):
    print(동물)
print("동물원 가zooA~~~~~~~")
# Out:
# 토끼
# 사자
# 푸바오
# 호랑이
# 동물원 가zooA~~~~~~~
