# %% [markdown]
# 함수를 정의할 때 사용하는 매개변수의 개수와 호출시 입력되는 매개변수의 개수는 동일해야 한다.
#
# ```
# # 선언과 호출에 사용된 매개변수는 2개
# def oz(message, n):
# &emsp;for i in range(n):
# &emsp;&emsp;print(message)
#
# oz('oz코딩스쿨', 5)
# ```
# &emsp;1. 매개변수를 적게 입력했을 때
# &emsp;2. 매개변수를 많이 입력 했을 때

# %%
# 매개변수를 적게 입력했을 때

def oz(message, n):
    for i in range(n):
        print(message)

oz('oz코딩스쿨')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-63d1a8ced450> in <cell line: 7>()
#       5         print(message)
#       6
# ----> 7 oz('oz코딩스쿨')
#
# TypeError: oz() missing 1 required positional argument: 'n'

# %%
# 매개변수를 많이 입력했을 때

def oz(message, n):
    for i in range(n):
        print(message)

oz('oz코딩스쿨', 5, 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-a30b31364611> in <cell line: 7>()
#       5         print(message)
#       6
# ----> 7 oz('oz코딩스쿨', 5, 5)
#
# TypeError: oz() takes 2 positional arguments but 3 were given

# %%
print('값을 많이 넣는 방법은', '쉼표로 구분해서', 3, 4, '문자형과 상수형을 구분해서')
# Out:
# 값을 많이 넣는 방법은 쉼표로 구분해서 3 4 문자형과 상수형을 구분해서

# %% [markdown]
# ```
# # 함수 구조
# def 함수이름(매개변수, *가변 매개변수):
#     코드
# ```

# %%
def oz(n, *values):
    for i in range(n):
        for value in values:
            print(value)
        print()

oz(3, "이렇게", "저렇게", "가변 매개변수는 요렇게")

# %%
# 가변 매개변수의 오류
def oz(*values, n):
    for i in range(n):
        for value in values:
            print(value)
        print()

oz(3, "이렇게", "저렇게", "가변 매개변수는 요렇게")

# 함수 호출 시 전달된 값에서 어디까지가 가변 매개변수이고 어떤 값이 n 식별자에 전달되는지 판단이 안되기 때문.

# %%
def oz(n, *ff):
    for i in range(n):
        for value in ff:
            print(value)
        print()

oz(3, "이렇게", "저렇게", "가변 매개변수는 요렇게")
# Out:
# 이렇게
# 저렇게
# 가변 매개변수는 요렇게
#
# 이렇게
# 저렇게
# 가변 매개변수는 요렇게
#
# 이렇게
# 저렇게
# 가변 매개변수는 요렇게

# %% [markdown]
# ###단, 가변 매개변수를 사용하기 위해서는 2가지 주의점이 있다.
#
# *   가변 매개변수 뒤에는 일반 매개변수가 올 수 없다.
# *   가변 매개변수는 하나만 사용할 수 있다.
#
# #### 가변 매개변수의 특징
#
# * 가변인 만큼 값을 여러개 작성할 수 있다.

# %% [markdown]
# ### 이해도 테스트
#
# - 가변 매개 변수를 사용하는 이유 설명
# - 가변 매개 변수를 사용하기 위한 문법
# - 가변 매개 변수를 사용하기 위한 제약 조건

# %%
# 1. 가변 매개 변수를 사용하는 이유
# 여러개의 값을 한 번에 호출할 때, 매개변수를 다수 작성하면 효율성, 가독성, 매개변수의 혼동이 올 수 있기 때문에 가변 매개변수를 선언 후 값을 작성한다.
# 여러 값을 자주 바꾸더라도 모든 매개변수를 바꿀 필요 없이, 최종 값만 변경해도 괜찮다.

# 2. 가변 매개 변수를 사용하기 위한 문법
# def oz(n(매개변수), *valuse(*을 붙임으로 가변 매개변수 선언))
    # 코드

# 3. 가변 매개 변수 사용의 제약 조건
# 가변 매개 변수 뒤에는 일반 매개 변수가 올 수 없다.
# 가변 매개 변수는 하나만 선언할 수 있다. ex) def oz(n, *n, *n)은 불가능
