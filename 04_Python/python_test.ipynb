# %% [markdown]
# #안녕하세요
# ##안녕하세요
# ###안녕하세요
# ####안녕하세요
# #####안녕하세요
# ######안녕하세요

# %%
print('안녕하세요')
# Out:
# 안녕하세요

# %%
print("안녕하세요")
# Out:
# 안녕하세요

# %%
print('안녕하세요')
# Out:
# 안녕하세요

# %%
2+3
2+4
# Out:
# 6
