# %% [markdown]
# def 게임():
# print('hello')
# 와
# 일반적인 프린트문으로 출력하는 것의 차이

# %% [markdown]
# ##백엔드의 데일리 업무
#  - 업무처리(하지만 생각보다 코드 치는 시간이 많지 않을 수 있음 -> 회사가 커질수록 코드를 많이 짜지 않음.) / 잔디블로그 참조
#  - 배포
#  - 온콜
#  - 장애대응
#  - 비용 최적화
#   - DB 쿼리 개선
#   - API 최적화
#   - 캐싱 개선 등...(레이턴시 줄이기)

# %% [markdown]
# ##파이썬 백엔드 개발자의 장점
# 1. 백엔드 개발자
#   - 회사에서 보통 중요한 역할
# 2. python
#   - 원하는 것을 빠르게 구현가능
#   - 라이브러리가 매우 풍부

# %% [markdown]
# ##파이썬 백엔드 개발자의 단점
# 1. 백엔드 개발자
#   - 커뮤니케이션
#     - 회의가 너무 많음
#       -PO(Product Owner), 프엔개발자, 백엔드 내부 논의 등
#   - 온콜의 힘듦
#     - 새벽 시간
#   - 야근이 생각보다 많음
# 2. Python
#   - 문법이 자유로워서 유지보수가 어려움

# %% [markdown]
# ##Python 백엔드 외 Python 직무
# 1. MLOps
# 2. 데이터 엔지니어
#     - EDW(Enterprice Data Warehouse)
#     - **사용 스택**
#         - pyspark
#         - flink
#         - airflow

# %% [markdown]
# ##Key Takeaways
# 1. 파이썬 공부하는 방법 : leetcode
#     - 취업 후 빡세게 돌릴때
#     - https://leetcode.com/problemset/
#     - 그 외, 프로그래머스랑 백준 온라인 저지(백준은 문제수가 많음)
# 2. CS 지식을 더할수록 프로그래밍 깊이가 깊어짐
#     - garbage collection(instagram)
#     - https://instagram-engineering.com/dismissing-python-garbage-collection-at-instagram-4dca40b29172
#     - disk io 줄이기 redis
#     - 실제 프로그램이 동작되는 방법(C언어 어셈블리)
#         - real time

# %% [markdown]
# docker나 docker-compose를 많이 활용하고
# kuberntes는 초보자가 건드릴 것은 아직 아님
# - 이쪽을 배워놓으면 dev-ops쪽으로 넘어갈 수 있음.

# %%
word_number = {
    "zero": "0",
    "one": "1",
    "two": "2",
    "three": "3",
    "four": "4",
    "five": "5",
    "six": "6",
    "seven": "7",
    "eight": "8",
    "nine": "9"
}

s = "77three4one"

for i in word_number.keys():
    s = s.replace(i, word_number[key])

print(s)
# Out:
# 77949
